# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('USD_RUB.csv')
df1 = df.reindex(columns = ['Date','Price'])

# %%
df
# Out:
#              Date    Price     Open     High      Low Change %
# 0     Apr 14 2022  80.9957  79.8675  82.3836  79.8563    1.41%
# 1     Apr 13 2022  79.8675  79.6800  80.2965  79.4078    0.24%
# 2     Apr 12 2022  79.6800  79.0650  80.2549  78.6952    0.78%
# 3     Apr 11 2022  79.0650  76.0800  81.2950  76.0800    3.92%
# 4     Apr 08 2022  76.0800  75.7500  76.2590  71.3993    0.44%
# ...           ...      ...      ...      ...      ...      ...
# 5315  Sep 20 2001  29.4300  29.4550  29.4760  29.4030   -0.08%
# 5316  Sep 19 2001  29.4530  29.4600  29.4810  29.4300   -0.02%
# 5317  Sep 18 2001  29.4600  29.4450  29.4750  29.4400   -0.00%
# 5318  Sep 17 2001  29.4610  29.4600  29.4730  29.4400   -0.04%
# 5319  Sep 14 2001  29.4730  29.3500  29.4800  29.3500   -0.00%
#
# [5320 rows x 6 columns]

# %%
df1.Date= pd.to_datetime(df.Date)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5320 entries, 0 to 5319
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5320 non-null   datetime64[ns]
#  1   Price   5320 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 83.2 KB

# %%
## transformando a variavel ''Date'' em datetime ##
df2 = df1[df1['Date' ] > '2015-01-1']
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1852 entries, 0 to 1851
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1852 non-null   datetime64[ns]
#  1   Price   1852 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 43.4 KB

# %%
df2.set_index('Date', inplace=True)

# %%
## e em seguida transformarei a coluna Date como uma coluna indexadora dos demais ultilizando o comando Data.frame.set_index(). ##

# %%
df2.plot(figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## pegar a variavel Price e fazer com o número de exportação ##
## fazer um grafico de variação de cada, depois comparar os dois##

# %%
df1= df1.iloc[::-1]

# %%
df2.plot(figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(18, 8)) 
  
plt.plot(df2) 

plt.tick_params(axis='y', which='both', right=False, 
                left=False, labelleft=False) 
plt.title('Rublo Russo em relação ao Dolar', fontsize=18)

for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
plt.show() 
##inverter de 2001>2022##
## cortar data da taxa de cambio ##

# %%
df3 = pd.read_csv(r'C:\Users\ahcar\Downloads\USD_UAH Dados Históricos (1).csv')

# %%
df3
# Out:
#           Data   Último Abertura   Máxima   Mínima    Var%
# 0   05.07.2022  29,5437  29,4000  29,5485  29,4000   1,00%
# 1   04.07.2022  29,2500  29,4000  29,5485  29,3987   0,00%
# 2   01.07.2022  29,2500  29,5437  29,5485  29,3987   0,00%
# 3   30.06.2022  29,2500  29,4000  29,5475  29,3987  -0,85%
# 4   29.06.2022  29,5000  29,5437  29,5450  29,3987   0,00%
# 5   28.06.2022  29,5000  29,4000  29,5450  29,3987  -0,14%
# 6   27.06.2022  29,5400  29,4000  29,5450  29,3987   0,00%
# 7   24.06.2022  29,5400  29,5437  29,5485  29,3987   0,00%
# 8   23.06.2022  29,5400  29,5485  29,5485  29,3987   0,99%
# 9   22.06.2022  29,2500  29,4025  29,5485  29,3987   0,00%
# 10  21.06.2022  29,2500  29,4000  29,5485  29,3987   0,00%
# 11  20.06.2022  29,2500  29,5485  29,5485  29,3987  -0,98%
# 12  17.06.2022  29,5400  29,4000  29,5500  29,3987  -0,02%
# 13  16.06.2022  29,5450  29,4025  29,5500  29,3987   1,01%
# 14  15.06.2022  29,2500  29,5437  29,5500  29,3987  -0,98%
# 15  14.06.2022  29,5400  29,4000  29,5500  29,3987   0,99%
# 16  13.06.2022  29,2500  29,5237  29,5500  29,3987  -1,00%
# 17  10.06.2022  29,5450  29,4000  29,5500  29,3987  -0,00%
# 18  09.06.2022  29,5462  29,5437  29,5485  29,4000   0,02%
# 19  08.06.2022  29,5400  29,4000  29,5450  29,3987  -0,01%
# 20  07.06.2022  29,5420  29,4000  29,5485  29,3987   0,14%
# 21  06.06.2022  29,5000  29,4000  29,5250  29,3987   0,85%
